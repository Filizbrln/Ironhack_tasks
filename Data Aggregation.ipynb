# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r"C:\Users\oezkan\Desktop\DATA_WEITERBILDUNG\IRONHACK\TASKS\2.week\Custemers_aggregation\file1.csv")

# %%
df2 = pd.read_csv(r"C:\Users\oezkan\Desktop\DATA_WEITERBILDUNG\IRONHACK\TASKS\2.week\Custemers_aggregation\file2.csv")

# %%
df1.head(10)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
df2.head(10)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
df1["Customer"].unique()
# Out:
# array(['RB50392', 'QZ44356', 'AI49188', ..., 'CW49887', 'MY31220', nan],
#       dtype=object)

# %%
df2['Customer'].unique()
# Out:
# array(['GS98873', 'CW49887', 'MY31220', 'UH35128', 'WH52799', 'WL99637',
#        'UC84059', 'HW62747', 'BH11344', 'TX28465', 'OK56965', 'WT22392',
#        'PH85036', 'KC71643', 'NR32615', 'GS69842', 'WT71621', 'KD23847',
#        'PE59368', 'NK91488', 'CR33417', 'WP73172', 'PS30217', 'EL62967',
#        'MU23938', 'VC83809', 'VL34577', 'QE12539', 'YO15246', 'WF73839',
#        'TJ11671', 'SV34223', 'XD19546', 'OY95739', 'SW57539', 'IA62027',
#        'FZ20933', 'WR62597', 'KU61611', 'XW98867', 'PP80817', 'DT77901',
#        'DX34647', 'OD56551', 'OO63074', 'EH24828', 'CX99919', 'DG80424',
#        'NU32697', 'PU98976', 'ZR20842', 'NF35573', 'DF66914', 'YM99866',
#        'VH62084', 'SE28250', 'MD86050', 'GF17866', 'UB16654', 'KO44736',
#        'KI55845', 'JJ24476', 'VC68509', 'QN62502', 'EL92515', 'VL84149',
#        'JX19907', 'BC66921', 'RK24470', 'GN80437', 'AH65907', 'VG57728',
#        'AF81450', 'YI28422', 'GR26937', 'BR99015', 'PB11270', 'PZ89632',
# ...

# %%
set(df1["Customer"].unique()).intersection(set(df2["Customer"].unique()))
# Out:
# {'CW49887', 'GS98873', 'MY31220'}

# %%
df1['Customer Lifetime Value'][df1['Customer'] == 'CW49887']
# Out:
# 1069    462680.11%
# Name: Customer Lifetime Value, dtype: object

# %%
df2['Customer Lifetime Value'][df2['Customer'] == 'CW49887']
# Out:
# 1    462680.11%
# Name: Customer Lifetime Value, dtype: object

# %%
df2['Income'][df2['Customer'] == 'CW49887']
# Out:
# 1    79487
# Name: Income, dtype: int64

# %%
df1['Income'][df1['Customer'] == 'CW49887']
# Out:
# 1069    79487.0
# Name: Income, dtype: float64

# %%
df2['Income'] = df2['Income'].astype('float64')

# %%
df3 = pd.merge(df1, df2,how='outer')

# %%
df3.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
len(df1)
# Out:
# 4008

# %%
df1['Total Claim Amount'][df1['Customer'] == 'CW49887']
# Out:
# 1069    547.2
# Name: Total Claim Amount, dtype: float64

# %%
df2['Total Claim Amount'][df2['Customer'] == 'CW49887']
# Out:
# 1    547.2
# Name: Total Claim Amount, dtype: float64

# %%
len(df2)
# Out:
# 996

# %%
len(df3)
# Out:
# 5001

# %%
df3.describe().T
# Out:
#                        count          mean           std        min  \
# Income                2064.0  39506.675872  30338.414847   0.000000
# Monthly Premium Auto  2064.0    169.289729   1219.971732  61.000000
# Total Claim Amount    2064.0    410.833935    283.192990   0.382107
#
#                                25%      50%           75%           max
# Income                15162.750000  36509.0  64289.500000  99981.000000
# Monthly Premium Auto     68.000000     81.0    108.000000  35354.000000
# Total Claim Amount      245.354739    350.4    523.815839   2893.239678

# %%
df3.rename(columns={"Customer":"CID", "ST":"state", "GENDER":"gender", "Education":"degree"
                    ,"Customer Lifetime Value":"clv", "Monthly Premium Auto":"premium", "Number of Open Complaints":"complaints"
                   , "Policy Type":"policy", "Vehicle Class":"class", "Total Claim Amount":"claim"}, inplace = True)

# %%
df3.head() #CID -->Customer ID
# Out:
#        CID       state gender                degree          clv   Income  \
# 0  RB50392  Washington    NaN                Master          NaN      0.0
# 1  QZ44356     Arizona      F              Bachelor   697953.59%      0.0
# 2  AI49188      Nevada      F              Bachelor  1288743.17%  48767.0
# 3  WW63253  California      M              Bachelor   764586.18%      0.0
# 4  GA49547  Washington      M  High School or Below   536307.65%  36357.0
#
#    premium complaints          policy          class        claim
# 0   1000.0     1/0/00   Personal Auto  Four-Door Car     2.704934
# 1     94.0     1/0/00   Personal Auto  Four-Door Car  1131.464935
# 2    108.0     1/0/00   Personal Auto   Two-Door Car   566.472247
# 3    106.0     1/0/00  Corporate Auto            SUV   529.881344
# 4     68.0     1/0/00   Personal Auto  Four-Door Car    17.269323

# %%
df3["clv"].fillna("0%", inplace = True)

# %%
df3["clv"] = df3["clv"].apply(lambda x:x[:-1])

# %%
df3["clv"].value_counts()
# Out:
# 0             2944
# 552821.28        5
# 251459.20        5
# 343613.43        4
# 650339.70        4
#               ...
# 575991.08        1
# 1511440.24       1
# 988038.58        1
# 2919436.64       1
# 399258.39        1
# Name: clv, Length: 1924, dtype: int64

# %%
df3.head()
# Out:
#        CID       state gender                degree         clv   Income  \
# 0  RB50392  Washington    NaN                Master           0      0.0
# 1  QZ44356     Arizona      F              Bachelor   697953.59      0.0
# 2  AI49188      Nevada      F              Bachelor  1288743.17  48767.0
# 3  WW63253  California      M              Bachelor   764586.18      0.0
# 4  GA49547  Washington      M  High School or Below   536307.65  36357.0
#
#    premium complaints          policy          class        claim
# 0   1000.0     1/0/00   Personal Auto  Four-Door Car     2.704934
# 1     94.0     1/0/00   Personal Auto  Four-Door Car  1131.464935
# 2    108.0     1/0/00   Personal Auto   Two-Door Car   566.472247
# 3    106.0     1/0/00  Corporate Auto            SUV   529.881344
# 4     68.0     1/0/00   Personal Auto  Four-Door Car    17.269323

# %%
df3["clv"] = df3["clv"].astype("float64")

# %%
df3.dtypes
# Out:
# CID            object
# state          object
# gender         object
# degree         object
# clv           float64
# Income        float64
# premium       float64
# complaints     object
# policy         object
# class          object
# claim         float64
# dtype: object

# %%
df3.head()
# Out:
#        CID       state gender                degree         clv   Income  \
# 0  RB50392  Washington    NaN                Master        0.00      0.0
# 1  QZ44356     Arizona      F              Bachelor   697953.59      0.0
# 2  AI49188      Nevada      F              Bachelor  1288743.17  48767.0
# 3  WW63253  California      M              Bachelor   764586.18      0.0
# 4  GA49547  Washington      M  High School or Below   536307.65  36357.0
#
#    premium complaints          policy          class        claim
# 0   1000.0     1/0/00   Personal Auto  Four-Door Car     2.704934
# 1     94.0     1/0/00   Personal Auto  Four-Door Car  1131.464935
# 2    108.0     1/0/00   Personal Auto   Two-Door Car   566.472247
# 3    106.0     1/0/00  Corporate Auto            SUV   529.881344
# 4     68.0     1/0/00   Personal Auto  Four-Door Car    17.269323

# %%
df3["complaints"].value_counts()
# Out:
# 1/0/00    1623
# 1/1/00     247
# 1/2/00      93
# 1/3/00      60
# 1/4/00      29
# 1/5/00      12
# Name: complaints, dtype: int64

# %%
df3.dtypes
# Out:
# CID            object
# state          object
# gender         object
# degree         object
# clv           float64
# Income        float64
# premium       float64
# complaints     object
# policy         object
# class          object
# claim         float64
# dtype: object

# %%
df3.head(100)
# Out:
#         CID       state gender                degree         clv   Income  \
# 0   RB50392  Washington    NaN                Master        0.00      0.0
# 1   QZ44356     Arizona      F              Bachelor   697953.59      0.0
# 2   AI49188      Nevada      F              Bachelor  1288743.17  48767.0
# 3   WW63253  California      M              Bachelor   764586.18      0.0
# 4   GA49547  Washington      M  High School or Below   536307.65  36357.0
# ..      ...         ...    ...                   ...         ...      ...
# 95  TV87155      Oregon    NaN              Bachelor  2094619.25  69738.0
# 96  KH48895          AZ    NaN                Master   837535.39  17780.0
# 97  NZ30757  California    NaN              Bachelor   480166.15  18107.0
# 98  RI22468          AZ    NaN              Bachelor   574594.33  57740.0
# 99  FZ30935      Oregon    NaN               College   606611.60  32627.0
#
#     premium complaints          policy          class        claim
# ...

# %%
df3[df3['complaints'] == '1/1/00']
# Out:
#           CID       state gender                degree         clv   Income  \
# 13    SJ95423     Arizona    NaN  High School or Below   881901.89  99845.0
# 15    BW63560      Oregon    NaN              Bachelor   746313.94  24599.0
# 21    QK46697  Washington      M             Bachelors   617710.93  61040.0
# 29    EJ77678      Oregon    NaN                Master   323536.05  75690.0
# 30    SV85652     Arizona    NaN               College   245458.35  23158.0
# ...       ...         ...    ...                   ...         ...      ...
# 4957  KN25124      Oregon      F                Master   245681.66  50979.0
# 4959  MS18916  California      M               College   350856.95  20978.0
# 4967  ZN24083      Oregon      M                Doctor   553246.23  29084.0
# 4968  JU74347      Oregon      M              Bachelor   794351.33  60214.0
# 4983  KJ23009  California      F              Bachelor  1059854.25  20179.0
#
# ...

# %%
df3["complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan],
#       dtype=object)

# %%
df3["complaints"].value_counts()
# Out:
# 1/0/00    1623
# 1/1/00     247
# 1/2/00      93
# 1/3/00      60
# 1/4/00      29
# 1/5/00      12
# Name: complaints, dtype: int64

# %%
df3["complaints"].isna().sum()
# Out:
# 2937

# %%
for i in df3["complaints"].value_counts():
    print(i)
# Out:
# 1623
# 247
# 93
# 60
# 29
# 12

# %%
# I will try to change na values with mean of number of days
def average_weekday():
    total = 0
    for i, v in enumerate(df3["complaints"].value_counts()):
        total += int(i) * v
    return total//sum(df3["complaints"].value_counts())

# %%
average_weekday()
# Out:
# 0

# %%
df3["complaints"].fillna("1/0/00", inplace = True)

# %%
df3["complaints"].value_counts()
# Out:
# 1/0/00    4560
# 1/1/00     247
# 1/2/00      93
# 1/3/00      60
# 1/4/00      29
# 1/5/00      12
# Name: complaints, dtype: int64

# %%
df3["complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00'],
#       dtype=object)

# %%
df3["complaints"] = df3["complaints"].apply(lambda datestr: '0' + datestr)

# %%
df3["complaints"]
# Out:
# 0       01/0/00
# 1       01/0/00
# 2       01/0/00
# 3       01/0/00
# 4       01/0/00
#          ...
# 4996    01/0/00
# 4997    01/0/00
# 4998    01/0/00
# 4999    01/0/00
# 5000    01/0/00
# Name: complaints, Length: 5001, dtype: object

# %%
df3["complaints"] = pd.to_datetime(df3["complaints"], format = "%m/%w/%y")

# %%
df3.dtypes
# Out:
# CID                   object
# state                 object
# gender                object
# degree                object
# clv                  float64
# Income               float64
# premium              float64
# complaints    datetime64[ns]
# policy                object
# class                 object
# claim                float64
# dtype: object
